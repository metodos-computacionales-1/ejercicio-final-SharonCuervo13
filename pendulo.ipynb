# %%
import matplotlib.pylab as plt
import numpy as np
from IPython.display import clear_output

# %%
# %%bash
# g++ pendulo.cpp
# ./a.out 10000000 > pendulo.txt

# %%
pendulo = np.genfromtxt("pendulo.txt")

time = pendulo[:,0]
theta = pendulo[:,1]
omega = pendulo[:,2]

# %%
plt.figure(figsize=(16,3))
plt.plot(time, theta, c="b")
plt.xlabel("tiempo (s)")
plt.ylabel("$\Theta$")
plt.title('pendulo')
plt.savefig("pendulo.png")
plt.show()
