# %%
import matplotlib.pylab as plt
import numpy as np
from IPython.display import clear_output

# %%
# %%bash
# g++ pend.cpp
# ./a.out 600 >pend.txt

# %%
Bifurca = np.genfromtxt("pend.txt")

Fd = Bifurca[:,0]
theta = Bifurca[:,1]
theta[227:]+=2*np.pi

# %%
plt.figure(figsize=(10,6))
plt.scatter(Fd,theta,s=5,c='maroon')
plt.xlabel('sFd')
plt.ylabel('Theta')
plt.savefig("bifurcacion.png")
plt.show()
